# %% [markdown]
# Question 5
# Use Gutenberg and Web_text data. Find out what are the top 5 words that Shakespeare used but we do not use in currently. Take top 50 words from Shakespeare (all 3 books) and top 50 from Web_text (all the records). Remove punctuation and stop words. Remove the words we still use today, and get the unused list. Show the top 5 elements.

# %%
import nltk

# %%
from nltk.corpus import gutenberg

# %%
nltk.corpus.gutenberg.fileids()
# Out:
# ['austen-emma.txt',
#  'austen-persuasion.txt',
#  'austen-sense.txt',
#  'bible-kjv.txt',
#  'blake-poems.txt',
#  'bryant-stories.txt',
#  'burgess-busterbrown.txt',
#  'carroll-alice.txt',
#  'chesterton-ball.txt',
#  'chesterton-brown.txt',
#  'chesterton-thursday.txt',
#  'edgeworth-parents.txt',
#  'melville-moby_dick.txt',
#  'milton-paradise.txt',
#  'shakespeare-caesar.txt',
#  'shakespeare-hamlet.txt',
#  'shakespeare-macbeth.txt',
#  'whitman-leaves.txt']

# %%
words1=gutenberg.words('shakespeare-caesar.txt')
words2=gutenberg.words('shakespeare-hamlet.txt')
words3=gutenberg.words('shakespeare-macbeth.txt')
total_words=words1+words2+words3
print(total_words)
# Out:
# ['[', 'The', 'Tragedie', 'of', 'Julius', 'Caesar', ...]

# %%
fdist1= nltk.FreqDist(total_words);

# %%
vocabulary1=fdist1.keys()

# %%
print(vocabulary1)
# Out:
# dict_keys(['seauenth', 'rous', 'refus', 'Speake', 'presage', 'vniust', 'Gray', 'posset', 'cuts', 'assurance', 'inexplicable', 'solemne', 'faire', 'Iaw', 'Sir', 'threat', 'purpled', 'Neighbors', 'assumes', 'Mightier', 'circumscrib', 'Kibe', 'expell', 'Banquoh', 'away', 'reserue', 'Reply', 'Natures', 'tyred', 'couched', 'gain', 'opposed', 'Ore', 'duties', 'eruptions', 'got', 'vnderstood', 'Ministers', 'Artlesse', 'inuisible', 'depend', 'Rudenesse', 'heauenly', 'Scene', 'found', 'bloud', 'ratifie', 'sauing', 'wife', 'sacrilegious', 'Shake', 'Knocking', 'stricken', 'Scullion', 'maruell', 'grand', 'Whole', 'declines', 'somewhat', 'proclaimes', 'vntrod', 'loues', 'celebrates', 'Extorted', 'learn', 'predominance', 'flattering', 'Crown', 'furious', 'Concord', 'Gouts', 'm', 'marry', 'Foiles', 'Hands', 'rides', 'bolter', 'stroken', 'Rookes', 'Hearts', 'Low', 'wings', 'shapes', 'Damnation', 'Reuiuing', 'Acheron', 'ostentation', 'Dwell', 'calculate', 'Aleppo', 'crash', 'saluted', 'supporting', 'Ha', 'Scarffes', 'inhabit', 'fatter', 'No', 'lifted', 'Phoebus', 'Sleep', 'Goodman', 'touching', 'vision', 'Robe', 'rac', 'referr', 'leauing', 'whither', 'stares', 'mutiny', 'Gainst', 'Destinie', 'Pleas', 'pale', 'Natiue', 'ioyfully', 'great', 'innocent', 'Cæsar', 'late', 'Seale', 'Fate', 'Moity', 'amaz', 'shed', 'substance', 'weedy', 'Deci', 'Cosine', 'adde', 'Wee', 'run', 'factious', 'last', 'issue', 'tread', 'doore', 'Quintus', 'get', 'greets', 'Orator', 'Weapons', 'Tyrant', 'essentially', 'describ', 'Though', 'batter', 'chid', 'Story', 'Garden', 'Immortall', 'ten', 'fairest', 'runs', 'Neats', 'We', 'nice', 'Dismay', 'Clownes', 'Mew', 'Hearsed', 'Quintessence', 'Crow', 'bounteous', 'Clown', 'tyed', 'path', 'melodious', 'souldiers', 'thinkst', 'contract', 'speaks', 'euils', 'Fortitude', 'exact', 'heerein', 'odde', 'Nipple', 'Soules', 'Clit', 'backe', 'supernaturall', 'dishes', 'grant', 'play', 'greeuously', 'Passion', 'Sextons', 'Francisco', 'Slippes', 'Index', 'Receit', 'Heath', 'speak', 'Souldiers', 'Twere', 'stone', 'kettle', 'trembling', 'Boy', 'illume', 'Cesterne', 'perseuer', 'wring', 'too', 'picture', 'limed', 'Chiefe', 'Hie', 'Tooke', 'pretty', 'costly', 'Red', 'boyle', 'exterior', 'others', 'Potion', 'smeare', 'Cathnes', 'remaines', 'Deerer', 'Strato', 'Looser', 'summe', 'Scull', 'Brests', 'comply', 'Crying', 'Welcome', 'confidence', 'fencing', 'Marry', 'Deadmans', 'Hags', 'dearly', 'struts', 'farther', 'Maiesties', 'met', 'whit', 'open', 'desart', 'Volt', 'breefe', 'study', 'accustom', 'discomfort', 'miserable', 'restraine', 'Belzebub', 'comes', 'steals', 'son', 'built', 'hurtled', 'glow', 'hangs', 'Promis', 'Comedie', 'Globe', 'trespasse', 'dipping', 'Beetle', 'Cynna', 'direst', 'Osricke', 'burnes', 'forgiuenesse', 'Siluer', 'vnmake', 'Seyton', 'ne', 'Vessell', 'Soothsayer', 'performe', 'anoynted', 'mind', 'Mortalitie', 'Reuennew', 'Pe', 'Blasted', 'warrant', 'flushing', 'distract', 'whence', 'Lookes', 'power', 'arriu', 'stare', 'where', 'Melancholly', 'apale', 'assault', 'stirre', 'yea', 'Cast', 'Fox', 'Cauerne', 'Vulgar', 'Pipe', 'floate', 'bolts', 'calles', 'vanishest', 'contradict', 'vnruly', 'corrupted', 'Prophesie', 'warie', 'Shipwracking', 'declension', 'thoght', 'lawful', 'Graine', 'roares', 'intended', 'Macd', 'often', 'fierce', 'Possets', 'Throw', 'loosed', 'Deuoutly', 'Eates', 'T', 'compell', 'dang', 'swallowed', 'nearest', 'Eare', 'either', 'threatning', 'Watchers', 'apt', 'strewments', 'tryalls', 'Apron', 'Shee', 'Birth', 'confess', 'pine', 'seduc', 'wonted', 'noise', 'vnruffe', 'Auaricious', 'Fauors', 'Fie', 'Beasts', 'intermit', 'Nemian', 'Shaft', 'interim', 'myraculous', 'sixeteene', 'Sprinkle', 'figure', 'Gummes', 'Seyw', 'horse', 'Marke', 'mount', 'Gold', 'Clowne', 'humorous', 'inmost', 'Whose', 'surpriz', 'throw', 'fee', 'accuse', 'Dard', 'Obedience', 'value', 'instigations', 'wherein', 'kisse', 'Hold', 'carelesly', 'drest', 'pluck', 'Nobility', 'Inheritor', 'Cure', 'Guardian', 'time', 'pre', 'Dunsmane', 'Liars', 'Ar ...

# %%
from collections import Counter

# %%
word_counts=Counter(vocabulary1)

# %%
top_fifty=word_counts.most_common(50)

# %%
print(top_fifty)
# Out:
# [('seauenth', 1), ('rous', 1), ('refus', 1), ('Speake', 1), ('presage', 1), ('Gray', 1), ('posset', 1), ('cuts', 1), ('assurance', 1), ('inexplicable', 1), ('solemne', 1), ('faire', 1), ('Iaw', 1), ('receiued', 1), ('threat', 1), ('wings', 1), ('Neighbors', 1), ('assumes', 1), ('stinglesse', 1), ('circumscrib', 1), ('Contumely', 1), ('Banquoh', 1), ('away', 1), ('chid', 1), ('Reply', 1), ('Natures', 1), ('tyred', 1), ('couched', 1), ('gain', 1), ('opposed', 1), ('Ore', 1), ('giued', 1), ('eruptions', 1), ('vnderstood', 1), ('Ministers', 1), ('Artlesse', 1), ('inuisible', 1), ('depend', 1), ('Rudenesse', 1), ('heauenly', 1), ('Scene', 1), ('worse', 1), ('found', 1), ('bloud', 1), ('necessaries', 1), ('sauing', 1), ('wife', 1), ('sacrilegious', 1), ('competent', 1), ('loosed', 1)]

# %%
from nltk.corpus import webtext

# %%
nltk.corpus.webtext.fileids()
# Out:
# ['firefox.txt',
#  'grail.txt',
#  'overheard.txt',
#  'pirates.txt',
#  'singles.txt',
#  'wine.txt']

# %%
webwords1=webtext.words('firefox.txt')
webwords2=webtext.words('grail.txt')
webwords3=webtext.words('overheard.txt')
webwords4=webtext.words('pirates.txt')
webwords5=webtext.words('singles.txt')
webwords6=webtext.words('wine.txt')
total_webwords=webwords1+webwords2+webwords3+webwords4+webwords5+webwords6
print(total_webwords)
# Out:
# ['Cookie', 'Manager', ':', '"', 'Don', "'", 't', ...]

# %%
fdist2= nltk.FreqDist(total_webwords);

# %%
fdist2
# Out:
# FreqDist({'Kills': 1,
#           'spaces': 15,
#           'Gray': 1,
#           'Nutty': 3,
#           'clearly': 13,
#           'KNIGHT': 68,
#           'Crown': 1,
#           'browse': 10,
#           'Smiths': 1,
#           'Xopus': 1,
#           'Underline': 1,
#           'retarded': 18,
#           'rape': 11,
#           'quiet': 23,
#           'memorabilia': 1,
#           'museums': 2,
#           'minor': 5,
#           'undrinkability': 1,
#           'ALWAYS': 1,
#           'asthma': 1,
#           'trustworthy': 1,
#           'meathead': 1,
#           'dangles': 1,
#           'BUSINESSMAN': 4,
#           'cockroch': 1,
#           'pretend': 3,
#           'Shell': 1,
#           'material': 2,
#           'juiciness': 1,
#           'sinking': 1,
#           '::~': 1,
#           '0x80520012': 1,
#           'Nine': 2,
#           'addObserver': 1,
#           'Important': 1,
#           'evaded': 1,
#           'Suzy': 1,
#           'popub': 1,
#           'Guardian': 1,
#           'dm': 1,
#           'humans': 2,
#           'dealin': 1,
#           'Cheap': 1,
#           'Mother': 79,
#           'shoo': 4,
#           'unicode': 1,
#           'Suck': 5,
#           'decorated': 1,
#           'Warm': 2,
#           'hips': 1,
#           'ranking': 1,
#           'MASTER': 13,
#           'lentil': 1,
#           'shapes': 1,
#           'OVER': 1,
#           'supporting': 2,
#           'Dogs': 1,
#           'vaults': 1,
#           'No': 796,
#           'Pre': 2,
#           'dblClick': 1,
#           'featuring': 1,
#           'meetings': 6,
#           'Hidden': 2,
#           'Binding': 2,
#           'groom': 1,
#           'ENH': 4,
#           'AAA': 1,
#           'Larry': 2,
#           'servlet': 1,
#           'great': 96,
#           'VM': 1,
#           'Week2': 1,
#           'END': 1,
#           'punishing': 1,
#           'DVD': 6,
#           'march': 1,
#           'trigger': 4,
#           'sparring': 1,
#           'browserwindows': 2,
#           'merger': 1,
#           'Deletion': 2,
#           'mouthwatering': 4,
#           'snow': 15,
#           'Herbert': 2,
#           'nationality': 2,
#           'ip': 1,
#           'beds': 3,
#           'wage': 2,
#           'misaligned': 2,
#           'designed': 2,
#           'runs': 19,
#           'radio': 16,
#           'Diff': 1,
#           'klicking': 2,
#           'Nebraska': 3,
#           'faggot': 9,
#           'Forgiving': 1,
#           'unstyled': 2,
#           'tons': 8,
#           'Ellington': 2,
#           'speaks': 5,
#           'MATURE': 1,
#           'swabbing': 1,
#           'sterility': 1,
#           'starve': 1,
#           'reliable': 5,
#           'megaphone': 2,
#           'cancels': 2,
#           'play': 53,
#           'Polish': 12,
#           'Leroy': 1,
#           'Passion': 1,
#           'merge': 2,
#           'TextArea': 2,
#           'Preggers': 3,
#           'Possible': 3,
#           'Yasser': 3,
#           'Fetchez': 2,
#           ':///': 2,
#           'sorting': 10,
#           'Seaweed': 1,
#           'enhance': 3,
#           'Slavic': 2,
#           'interruption': 2,
#           'sequent': 1,
#           'parameter': 10,
#           'elevator': 13,
#           'grapple': 1,
#           'doesnot': 1,
#           'criticizes': 1,
#           'confidence': 1,
#           'Marry': 1,
#           'classification': 2,
#           'dearly': 1,
#           'Secured': 1,
#           'Ad': 2,
#           'TAINING': 1,
#           'babes': 1,
#           'consolidate': 1,
#           'graphs': 1,
#           'Unreasonably': 1,
#           'bicycle': 2,
#           'study': 9,
#           'uploaded': 1,
#           'anchors': 1,
#           'comes': 36,
#           'eisrequiem': 1,
#           'hangs': 84,
#           'crippled': 1,
#           'App': 3,
#           'Christ': 31,
#           'hired': 3,
#           'signon': 2,
#           'infant': 6,
#           'hostname': 1,
#           'differs': 4,
#           'Lovers': 1,
#           'Amtrak': 1,
#           'cloning': 5,
#           'gametimesonline': 1,
#           'colonoscopies': 1,
#           'enhancements': 3,
#           'sticky': 6,
#           'resizeTo': 1,
#           'handicap': 1,
#           'locked': 13,
#           'leafy': 6,
#           'Deployment': 1,
#           'availWidth': 1,
#           '?::': 1,
#           'Cast': 3,
#           'Klonopin': 3,
#           'abyss': 1,
#           '"-"': 1,
#           'increment': 3,
#           'scanable': 1,
#           'sub': 14,
#           'Thomas': 2,
#           'Marvel': 2,
#           'Chassagne': 5,
#           'Van': 1,
#           'table': 51,
#           'Clear': 21,
#           'Trail': 1,
#           'pockets': 2,
#           'clop': 39,
#           'often': 26,
#           'proposal': 1,
#           'cleanup': 3,
#           'unladen': 2,
#           'poured': 5,
#           'SITE': 1,
#           'provincial': 1,
#           'butcher': 1,
#           'jpeg': 4,
#           'T': 28,
#           'Rikers': 1,
#           'haunted': 2,
#           'glove': 1,
#           'Slutty': 2,
#           'R2': 1,
#           'Ireland': 1,
#           'satisfying': 3,
#           'Down': 20,
#           'III': 1,
#           '?!': 67,
#           'Annie': 1,
#           'debian': 2,
#           'terrorists': 1,
#           'cleared': 4,
#           'Clicking': 63,
#           'cfm': 2,
#           'configured': 4,
#           '6': 99,
#           'Yo': 141,
#           'imbedded': 1,
#           'GMail': 1,
#           'XPConnect': 1,
#           'penalties': 1,
#           'Treat': 1,
#           'Jock': 1,
#           'horse': 25,
#           'widowed': 2,
#           'Wheelbo': 1,
#           'skulls': 1,
#           'countdown': 1,
#           'sorted': 12,
#           '54yo': 1,
#           'spotlight': 1,
#           'swing': 4,
#           'employs': 1,
#           'acrobat': 4,
#           'Fucker': 2,
#           'wait': 56,
#           'Dancer': 2,
#           'culture': 1,
#           'intimidating': 1,
#           'slushie': 2,
#           '901': 1,
#           'Stairmaster': 1,
#           'Symantec': 1,
#           'dependency': 2,
#           'meaningful': 2,
#           'River': 3,
#           'Anybody': 3,
#           'commuting': 1,
#           'Flat': 1,
#           'acroread': 1,
#           'Fruitcake': 1,
#           'Shoot': 2,
#           'Tighter': 1,
#           'worships': 1,
#           'HIG': 1,
#           'produce': 8,
#           'mapy': 1,
#           'WinFrame': 1,
#           'nsIProfileInternal': 1,
#           'effortlessly': 1,
#           'Grouped': 2,
#           'SendGuestbook': 1,
#           'Koonunga': 1,
#           'whorebag': 1,
#           'Sean': 1,
#           'Barbados': 2,
#           'involving': 2,
#           'vacates': 1,
#           'pocket': 7,
#           'Terminal': 5,
#           'Applications': 2,
#           'Pointer': 1,
#           'Activate': 1,
#           'cruise': 2,
#           'nudie': 1,
#           'Pedro': 3,
#           'Praise': 1,
#           'nails': 6,
#           'men': 67,
#           'attempthing': 1,
#           'guests': 1,
#           'bottles': 22,
#           'Canada': 8,
#           'Dominican': 4,
#           'tolls': 1,
#           'Dreadlocked': 2,
#           'spoonful': 1,
#           'attract': 2,
#           'Terminator': 1,
#           'onBlur': 1,
#           '+.': 1,
#           '4x4': 1,
#           'shower': 12,
#           'relative': 7,
#           'Geisha': 1,
#           'button2': 1,
#           'Ehh': 2,
#           'testing': 1,
#           'mentally': 2,
#           'lean': 2,
#           'Studio': 1,
#           'saloon': 1,
#           'unzipped': 1,
#           'flood': 1,
#           'nerves': 1,
#           'Asians': 9,
#           'underlined': 3,
#           'Peas': 1,
#           'gobrowsing': 1,
#           'busty': 1,
#           'dingleberries': 2,
#           'currentProfile': 1,
#           'signaling': 1,
#           'shoelaces': 1,
#           'Chaste': 1,
#           'summon': 1,
#           'contextmenu': 3,
#           '171196': 1,
#           'Throwing': 1,
#           'Official': 4,
#           'sweetnes': 1,
#           'Reductive': 1,
#           'fossil': 1,
#           'oddity': 3,
#           'king': 13,
#           'prog': 1,
#           'ulasponsel': 1,
#           'located': 8,
#           'weariest': 1,
#           'password': 127,
#           'laws': 2,
#           'BO': 7,
#           'sheets': 6,
#           '62nd': 2,
#           'turned': 31,
#           'austerely': 1,
#           'ororatorical': 1,
#           'Uganda': 1,
#           '10': 58,
#           'overt': 1,
#           'Mousing': 2,
#           'bunk': 1,
#           'altered': 2,
#           'Major': 2,
#           'Butterscotch': 1,
#           'Garganega': 1,
#           'chances': 4,
#           'lasted': 1,
#           'Toffee': 2,
#           'PSC': 1,
#           'slowness': 1,
#           'Doors': 2,
#           'Errors': 5,
#           'commando': 1,
#           'suspicion': 1,
#           'formhistory': 2,
#           'voip': 1,
#           'Colour': 1,
#           'Britons': 11,
#           'awake': 1,
#           'flute': 1,
#           'Brazil': 3,
#           'faulty': 2,
#           'autocompletes': 1,
#           'Piquant': 2,
#           'Tour': 6,
#           'Secure': 4,
#           'balinka': 1,
#           'throwing': 9,
#           'anorexic': 10,
#           'ere': 2,
#           'permanentaly': 1,
#           'whether': 22,
#           'weekday': 1,
#           'Africans': 2,
#           'touching': 4,
#           'infection': 3,
#           'Before': 4,
#           'Meathead': 5,
#           'dudes': 4,
#           'MR': 1,
#           'Weekly': 2,
#           'males': 1,
#           'morbidly': 2,
#           'Peace': 3,
#           'fb8': 1,
#           'inplace': 1,
#           'strips': 4,
#           'creature': 6,
#           'carpeting': 1,
#           'Initialize': 1,
#           'DOWN': 1,
#           'redisplay': 1,
#           'softness': 1,
#           'SUBSTANCE': 1,
#           'Ya': 10,
#           'within': 36,
#           'ethical': 1,
#           'administration': 1,
#           'homeless': 31,
#           'Usually': 3,
#           '161st': 1,
#           'weightiness': 1,
#           'GetShrinkToFit': 1,
#           'ripping': 1,
#           'Greek': 11,
#           'Copied': 1,
#           'cities': 3,
#           'farmyardy': 2,
#           'PRINCE': 1,
#           'Sox': 6,
#           'Anthony': 4,
#           'pretzels': 1,
#           'Expansion': 2,
#           'punks': 1,
#           'frothy': 2,
#           'Dressed': 1,
#           'Asexual': 2,
#           'drinker': 13,
#           'Mum': 1,
#           'Million': 1,
#           'false': 14,
#           '<!--': 1,
#           'importing': 8,
#           'stated': 1,
#           'bindings': 2,
#           'Unquoted': 1,
#           'glimpse': 2,
#           'seems': 89,
#           'replies': 2,
#           'plugin': 57,
#           'reception': 2,
#           'mentioned': 6,
#           'Sidebars': 5,
#           'SBC': 2,
#           'Liquor': 1,
#           'idiosynchratic': 1,
#           'til': 11,
#           'vows': 1,
#           '92': 2,
#           'firstusa': 1,
#           'icky': 1,
#           'Shopping': 3,
#           'corrected': 2,
#           'menu': 465,
#           'documentation': 4,
#           'Plug': 10,
#           'timebomb': 1,
#           'volunteer': 2,
#           'wore': 8,
#           'atop': 2,
#           'speedy': 1,
#           'Sidebar': 39,
#           'Searchbar': 1,
#           'amegaproxy': 1,
#           ';-)': 1,
#           'Fordham': 2,
#           'Radically': 1,
#           'groins': 1,
#           'how': 291,
#           'Editing': 3,
#           'qualities': 2,
#           'frigerator': 1,
#           'debate': 2,
#           'OSX': 5,
#           'Wet': 2,
#           'Malformed': 4,
#           'perform': 6,
#           'fur': 1,
#           'intermittantly': 1,
#           'getcha': 2,
#           'Dunno': 1,
#           'Performer': 1,
#           'garden': 4,
#           'cranberry': 6,
#           'symbol': 11,
#           'stoner': 2,
#           'Some': 49,
#           'Simon': 4,
#           'honey': 36,
#           'reposition': 1,
#           'drip': 2,
#           'nude': 1,
#           'movin': 2,
#           'quip': 2,
#           'demo': 3,
#           'contrived': 1,
#           'Scuse': 1,
#           'kidneys': 1,
#           'dows': 1,
#           'depict': 1,
#           'finer': 2,
#           'divine': 2,
#           'fourth': 5,
#           'Googlebar': 1,
#           'Giraffe': 1,
#           'Merlot': 1,
#           'faster': 9,
#           'bears': 2,
#           'behaving': 1,
#           'pokes': 2,
#           'redirects': 6,
#           'Tab': 67,
#           'calipers': 1,
#           'Market': 2,
#           'the': 7318,
#           'Elizabeth': 72,
#           'silk': 1,
#           '18': 9,
#           'tags': 20,
#           'yaoi': 1,
#           'major': 6,
#           'Hard': 10,
#           'opener': 1,
#           'hide': 20,
#           'pun': 1,
#           'Dwayne': 1,
#           'Waiter': 21,
#           'team': 7,
#           'life': 87,
#           '59': 4,
#           'Leno': 1,
#           'Percocet': 1,
#           '!"...': 2,
#           'taut': 2,
#           'Syntax': 1,
#           'expletive': 1,
#           'Slate': 1,
#           'Assertion': 1,
#           'Uploaded': 1,
#           'beads': 2,
#           'Oreos': 1,
#           'drum': 1,
#           'BLAINE': 1,
#           'rules': 7,
#           '61': 2,
#           'Herbal': 2,
#           'kneecaps': 1,
#           'mixes': 1,
#           'prefill': 2,
#           'ReResolveStyleContext': 1,
#           'LORD': 34,
#           'sphincter': 1,
#           'Passing': 2,
#           '***(*)': 101,
#           'superstitious': 1,
#           'mem': 2,
#           'determine': 3,
#           'unknown': 11,
#           'Volleyball': 1,
#           'geometric': 1,
#           'JavaScript': 53,
#           'craziness': 1,
#           'gkcontent': 1,
#           'Subways': 1,
#           '@@': 1,
#           'negotiate': 3,
#           'observes': 1,
#           '*****': 53,
#           'os': 15,
#           'conservative': 7,
#           'robes': 1,
#           'Holliday': 1,
#           'nightfall': 1,
#           'action': 29,
#           'restored': 1,
#           'elapsed': 1,
#           'Fino': 2,
#           'Within': 1,
#           'Mem': 1,
#           'Sprite': 1,
#           'lake': 1,
#           'wharf': 1,
#           'nightclubs': 1,
#           'nsPrintSettings': 1,
#           'Damp': 1,
#           'diagnose': 1,
#           '".': 51,
#           'Gimme': 3,
#           'scrambled': 3,
#           'migrate': 4,
#           'shipped': 1,
#           'prefLabel': 1,
#           'wind': 15,
#           'hacked': 2,
#           'scripts': 8,
#           'Third': 5,
#           'Sunnyside': 1,
#           'Increase': 1,
#           'Renders': 1,
#           'Awoo': 1,
#           'serving': 4,
#           'Caribbean': 3,
#           'unusable': 12,
#           'EUROPEAN': 1,
#           'Rose': 3,
#           'Uncheck': 1,
#           'summoning': 1,
#           'dwarf': 1,
#           'blue': 16,
#           'An': 41,
#           '79': 1,
#           'chopped': 1,
#           'Pirates': 2,
#           'snowflakes': 1,
#           'dialogue': 13,
#           'nuthin': 3,
#           'canbe': 1,
#           'cheat': 3,
#           'cheating': 3,
#           'ability': 26,
#           'Prompted': 1,
#           'fishing': 13,
#           'vi': 1,
#           'thus': 2,
#           'Diarrheas': 1,
#           'clutching': 1,
#           'Ames': 1,
#           'score': 9,
#           'REAAALLLY': 1,
#           'ancient': 3,
#           'investigate': 3,
#           'Grand': 20,
#           'marrowbones': 1,
#           'Macon': 3,
#           'gamblin': 2,
#           'fixes': 1,
#           'deli': 3,
#           'Stewie': 2,
#           'reduced': 1,
#           '145th': 4,
#           'retracts': 1,
#           'reordering': 2,
#           'weeds': 1,
#           'specified': 19,
#           'Necrophiliac': 1,
#           'blocked': 31,
#           'had': 367,
#           'Spanish': 44,
#           'whaddaya': 1,
#           'IDN': 3,
#           'backgroun': 1,
#           'wrapping': 1,
#           'brand': 7,
#           'Wont': 2,
#           'This': 272,
#           'hope': 43,
#           'Pendragon': 1,
#           'modifying': 5,
#           'player': 11,
#           'freaking': 8,
#           'INSPECTOR': 5,
#           'expense': 3,
#           'feel': 112,
#           'Along': 1,
#           'Somebody': 4,
#           'So': 556,
#           'Gdk': 1,
#           'Media': 9,
#           'wart': 1,
#           'clear': 63,
#           'Royal': 7,
#           'injects': 1,
#           'quirk': 1,
#           'tackle': 6,
#           'Francisco': 1,
#           'capitalist': 1,
#           'inconsistent': 12,
#           '!*': 6,
#           'Design': 5,
#           'Forums': 1,
#           'anxious': 1,
#           'translate': 1,
#           'dr': 1,
#           'VICTORIAN': 1,
#           'views': 2,
#           'bought': 27,
#           'contagious': 1,
#           'hosed': 2,
#           'Uuh': 2,
#           'basketball': 4,
#           'squeezing': 2,
#           'Alan': 1,
#           'Tabs': 45,
#           'textual': 1,
#           'bones': 7,
#           'Downloads': 36,
#           'averting': 1,
#           'dangerously': 1,
#           'alps': 1,
#           'Sexual': 1,
#           'Copyright': 2,
#           'sooo': 3,
#           'bonnie': 1,
#           'Shee': 1,
#           'Nerve': 2,
#           'title': 39,
#           'fry': 2,
#           'Tweaking': 1,
#           'writting': 1,
#           'markers': 1,
#           'eml': 1,
#           'nigger': 16,
#           'scrawny': 1,
#           'Owner': 1,
#           'aspects': 1,
#           'relocate': 1,
#           'LATE': 1,
#           'commemorative': 1,
#           'wit': 2,
#           'WINDOWS': 1,
#           'caption': 1,
#           'trip': 6,
#           'Astoria': 2,
#           'NICE': 1,
#           'formidable': 1,
#           'dumb': 7,
#           'outer': 4,
#           'rest': 33,
#           'skeletor': 1,
#           'FF10PR1': 2,
#           'WindowsXP': 1,
#           'Forms': 5,
#           'finishing': 6,
#           'boyfriend': 52,
#           'queer': 23,
#           'Chu': 1,
#           'pointless': 1,
#           'unblock': 2,
#           'general': 20,
#           'lamest': 1,
#           'Sheer': 1,
#           'DONT': 1,
#           'Shopgirl': 8,
#           'tux': 1,
#           'Entery': 1,
#           'Reg': 1,
#           'carbs': 2,
#           'Defeat': 1,
#           'signs': 11,
#           'disclose': 1,
#           'duel': 5,
#           'IIS': 1,
#           'GOOD': 2,
#           'easy': 52,
#           'topmenu': 1,
#           'endless': 7,
#           'wanting': 1,
#           'DEAS': 1,
#           '],': 2,
#           'SP2': 1,
#           'hidden': 24,
#           'recognizeable': 1,
#           'problems': 49,
#           'downarrow': 1,
#           'dog': 120,
#           'mimeTypes': 1,
#           'fleshy': 3,
#           'diploma': 1,
#           'RIGHT': 7,
#           'Livejournal': 1,
#           'MozDev': 2,
#           'GNOME': 9,
#           'Intistieti': 1,
#           'www': 69,
#           'foreign': 7,
#           "'(": 1,
#           'dirtiest': 2,
#           'Tidyness': 1,
#           'MIT': 1,
#           'puzzle': 1,
#           'overlap': 8,
#           'ecky': 3,
#           'Spicey': 1,
#           'Dense': 3,
#           'slim': 28,
#           'op': 1,
#           'Regain': 1,
#           'breeds': 1,
#           'Huge': 5,
#           'Snuffleupagus': 2,
#           'Training': 1,
#           'Yquem': 1,
#           'Hurricane': 1,
#           'Cotes': 1,
#           'headline': 2,
#           'identity': 1,
#           'Bowie': 1,
#           'continuous': 5,
#           'map': 15,
#           'Cockney': 1,
#           'ARTHUR': 225,
#           'wet': 14,
#           'Mediaplayer': 1,
#           'temprementally': 1,
#           'far': 33,
#           'Graham': 1,
#           'Ramonet': 1,
#           'ui': 2,
#           'scrolling': 66,
#           'emotion': 1,
#           'recreational': 1,
#           'gent': 6,
#           'FUUUCK': 1,
#           'stripper': 11,
#           'historian': 2,
#           'Larose': 1,
#           '163rd': 1,
#           'Audience': 3,
#           'Square': 34,
#           'Chapelle': 1,
#           'Hawaii': 1,
#           'MEAN': 1,
#           'Thief': 2,
#           'Tommy': 2,
#           'nitric': 1,
#           'write': 26,
#           'inches': 6,
#           'apricot': 4,
#           'true': 44,
#           'smell': 55,
#           'Linky': 1,
#           'Bump': 1,
#           'toasted': 2,
#           'matrimony': 1,
#           'GtkObject': 1,
#           'FIT': 6,
#           'Reese': 1,
#           'nearly': 13,
#           'telekenesis': 1,
#           'posse': 2,
#           'fully': 19,
#           'brighter': 1,
#           'Coming': 4,
#           'Positioned': 1,
#           'goin': 15,
#           'wade': 1,
#           'petetownshend': 1,
#           'feint': 1,
#           'GameBoy': 1,
#           'dare': 6,
#           'chess': 2,
#           'stale': 2,
#           'Rosa': 2,
#           'Ofoto': 1,
#           'Bernie': 1,
#           'Night': 2,
#           'readings': 2,
#           'Ihink': 1,
#           'Dock': 5,
#           'guide': 7,
#           'liege': 11,
#           'snap': 4,
#           'dressing': 7,
#           '19th': 2,
#           'Castro': 1,
#           'Off': 3,
#           'reporting': 1,
#           'viscous': 1,
#           'nosebleeds': 1,
#           'fair': 13,
#           'necessarily': 2,
#           'troubleshoot': 2,
#           'scents': 1,
#           'flash7player': 1,
#           'Gif': 1,
#           'messes': 6,
#           'HBO': 2,
#           'motha': 1,
#           'GTK': 4,
#           'chowder': 1,
#           'measure': 4,
#           'causing': 4,
#           'marmalade': 3,
#           'Called': 1,
#           'Rhodium': 1,
#           'apparantly': 1,
#           'choices': 5,
#           'ruler': 1,
#           'dim': 1,
#           'isn': 102,
#           'Drier': 4,
#           'jaguar': 1,
#           'knocks': 5,
#           'pressure': 3,
#           '60s': 2,
#           'prefrences': 1,
#           'twenty': 14,
#           'conversion': 1,
#           'Oooh': 16,
#           'Does': 51,
#           'Will': 159,
#           'startin': 1,
#           'FREE': 1,
#           'spaghetti': 1,
#           'weak': 1,
#           'tilted': 2,
#           'rewind': 1,
#           'Rounded': 10,
#           'desensitizing': 1,
#           'minded': 1,
#           'allow': 53,
#           'challah': 1,
#           'cements': 1,
#           'pre': 10,
#           'HERBERT': 26,
#           'chapped': 1,
#           'post': 11,
#           'CompositeEnumeratorImpl': 1,
#           'listing': 6,
#           'brisket': 1,
#           'appers': 1,
#           'Ahhh': 5,
#           'CD3': 1,
#           'net': 26,
#           'slashes': 2,
#           'past': 37,
#           'Poconos': 1,
#           'cleaned': 2,
#           'bitchtastic': 2,
#           'Asking': 1,
#           'positionafter': 1,
#           'descent': 1,
#           'eensy': 1,
#           'full': 69,
#           'natively': 1,
#           'suprnova': 1,
#           'Cabernet': 3,
#           'rink': 1,
#           'colourless': 2,
#           'Delicious': 12,
#           'convert': 1,
#           'otha': 1,
#           'Ohhh': 3,
#           'LOVING': 1,
#           'Allo': 2,
#           'playback': 1,
#           'nsViewManager': 1,
#           '78': 1,
#           'pick': 34,
#           'Tennessee': 4,
#           'Don': 150,
#           '79kg': 1,
#           'Seasonably': 1,
#           'since': 49,
#           'Standardized': 1,
#           'hunters': 1,
#           'Frogpad': 1,
#           '130th': 1,
#           'bounds': 1,
#           'namedItems': 1,
#           'Maybe': 70,
#           'Owen': 1,
#           'Corps': 2,
#           'nods': 8,
#           'ssl': 8,
#           'Crack': 2,
#           'onload': 4,
#           'Gotta': 3,
#           'twisted': 3,
#           'reaching': 1,
#           'printout': 1,
#           'intoxicated': 2,
#           'trippy': 1,
#           'where': 207,
#           'Pen': 3,
#           'bun': 1,
#           'toasty': 1,
#           'rabbi': 3,
#           'Ultra': 3,
#           'rivers': 1,
#           'Frat': 29,
#           'talked': 10,
#           'dimes': 1,
#           'Xilinx': 1,
#           'oo': 1,
#           'Metal': 3,
#           'sales': 6,
#           'LIRR': 2,
#           'less': 57,
#           'granted': 1,
#           'Patriot': 1,
#           'Chianti': 3,
#           '14th': 6,
#           'pouring': 3,
#           'scale': 6,
#           '...*!': 1,
#           'Aniseed': 2,
#           'erection': 1,
#           'onMouseOver': 1,
#           'Irishman': 4,
#           'Cuban': 1,
#           'CONCORDE': 12,
#           'notion': 2,
#           'repent': 1,
#           'placeholder': 1,
#           'printer': 7,
#           'aquatic': 1,
#           'guard': 18,
#           'Snob': 2,
#           'Weekend': 1,
#           ...})

# %%
vocabulary2=fdist2.keys()

# %%
print(vocabulary2)
# Out:
# dict_keys(['mood', 'physics', 'Kills', 'spaces', 'fooled', 'Gray', 'warheads', 'Paul', 'promises', 'height', 'inexplicable', 'Beta', 'Crown', 'browse', 'Smiths', 'tupayHey', 'assumes', 'Xopus', 'unsupported', 'Underline', 'URLS', 'STUNNER', 'retarded', 'rape', 'scheme', 'quiet', 'memorabilia', 'Waterhouse', 'waking', 'museums', 'minor', 'undrinkability', 'ALWAYS', 'evicted', 'scat', 'Impressive', "'...?)", 'asthma', 'trustworthy', 'meathead', 'dangles', 'BUSINESSMAN', 'Detect', 'blasts', 'Cops', 'found', 'Shell', 'Every', 'Liar', 'material', 'boats', 'wildcards', 'vine', 'clearly', 'sinking', 'RunTimeout', '0x80520012', 'recovering', 'KNIGHT', 'software', 'possibles', 'homies', 'Egyptians', 'Oddly', 'Tight', 'addObserver', 'minded', 'FirefoxHTML', 'Important', 'Apple', 'Scroll', 'craving', 'box', 'learn', 'Guardian', 'dm', 'incrementing', 'Mode', '02', 'stalker', 'Ewww', 'shoo', 'unicode', 'Fourth', 'm', 'Suck', 'bounce', 'Philippines', 'Generate', 'Ambiguously', 'Rounder', 'DS', 'renamed', 'thirteen', 'MASTER', 'fags', 'lentil', 'Loud', 'sushi', 'calculate', 'seldom', 'Guyy', 'crash', 'magical', 'spelling', 'supporting', 'Dogs', 'Uugh', 'mnemonics', 'hurries', 'No', 'Pre', 'visible', 'dblClick', 'thingy', 'remarked', 'Win2000', 'featuring', 'meetings', 'crush', 'Binding', 'Mushrooms', 'Gates', 'ENH', 'Grenade', 'Banner68', 'Street', 'dolly', 'ribs', 'valiant', 'Circuit', 'SPOILT', 'servlet', 'whistle', 'great', 'cataloguing', 'VM', 'unpredictably', '([', 'reorders', 'Week2', 'END', 'duff', 'Backward', 'app', 'Congeniality', 'labelling', 'run', 'Caramel', 'Tour', 'pastrami', 'issue', 'cured', 'browserwindows', 'seasoning', 'merger', 'Deletion', 'get', 'snow', 'Herbert', 'considerable', 'woah', 'ip', 'fairly', 'wage', 'sunshine', 'sophisticated', 'obscuring', 'OPML', 'letting', 'Bostonian', 'misaligned', 'printed', 'placenta', 'tropical', 'PEARL', 'formation', 'irregular', 'runs', 'radio', 'Diff', 'klicking', 'Nebraska', 'rim', 'faggot', 'Mew', 'Hispanic', 'kneel', 'merged', 'Conflict', '52yo', 'autofill', 'unstyled', 'path', 'tons', 'Ellington', 'speaks', 'blocks', '">"', 'firestone', 'exact', 'wildly', 'sterility', 'Como', 'crotch', 'reliable', 'lion', 'megaphone', 'Ampersand', 'cancels', 'play', 'Polish', 'Leroy', 'Passion', 'snotty', 'merge', 'TextArea', 'Getting', 'mountaintops', 'Gospel', 'cashew', 'floating', 'Preggers', 'Smart', 'Yasser', 'stone', 'flowers', 'legit', 'poet', 'Fetchez', ':///', 'sorting', 'conversion', 'too', 'horseback', ';&#', 'Sooo', 'scary', '+.', 'catheterize', 'RC', 'based', 'pet', 'delay', 'enhance', 'Slavic', 'Cross', 'foreigners', 'former', 'weirdest', 'interruption', 'pleasant', 'others', 'sequent', 'probing', 'parameter', 'intercontinental', 'Joe', 'Washington', 'elevator', 'hollow', 'cube', 'quotation', 'mplayerplug', 'doesnot', 'stepped', 'Roda', 'globby', 'VOICE', 'tutorial', 'Marry', 'classification', 'dearly', 'Secured', 'Ad', 'farther', 'babes', 'Unzipped', 'consolidate', 'graphs', 'nametag', 'Closes', 'crewman', 'bicycle', 'study', 'butterflies', 'Nursing', 'uploaded', 'gaping', 'anchors', 'comes', 'freedom', 'cockroch', 'immortal', 'previous', 'hangs', 'nosign', 'crippled', 'App', 'Christ', 'dispatcher', 'hired', 'torches', 'Scene', 'cares', 'hungrier', 'cooks', 'hostname', 'differs', 'Lovers', 'Amtrak', 'unfocussed', 'pretend', 'Noah', 'cloning', 'gametimesonline', 'colonoscopies', 'enhancements', 'Intriguing', 'closet', 'sticky', 'resizeTo', 'handicap', 'locked', 'Soy', 'fucker', 'lobotomy', 'Bull', 'Deployment', 'Whatchu', 'stare', 'Browser', 'Smells', 'Joyfully', 'assault', 'sport', '?::', 'Cast', 'attracted', 'perfumed', 'Klonopin', 'abyss', 'Rough', '250', '"-"', 'increment', 'scanable', 'sub', 'secure32', 'Separator', 'Thomas', 'juiciness', 'Marvel', 'regular', 'Croatia', 'table', 'thrashes', 'Clear', 'Valtrex', 'Twain', 'Checkin', 'pockets', 'grayed', 'clop', 'Trading', 'often', 'Freezes', 'proposal', 'Concerned', 'cleanup', 'Engineer', 'unladen', 'shrooms', 'SITE', 'Ease', 'so ...

# %%
word_counts2=Counter(vocabulary2)

# %%
top_fifty2=word_counts.most_common(50)

# %%
print(top_fifty2)
# Out:
# [('seauenth', 1), ('rous', 1), ('refus', 1), ('Speake', 1), ('presage', 1), ('Gray', 1), ('posset', 1), ('cuts', 1), ('assurance', 1), ('inexplicable', 1), ('solemne', 1), ('faire', 1), ('Iaw', 1), ('receiued', 1), ('threat', 1), ('wings', 1), ('Neighbors', 1), ('assumes', 1), ('stinglesse', 1), ('circumscrib', 1), ('Contumely', 1), ('Banquoh', 1), ('away', 1), ('chid', 1), ('Reply', 1), ('Natures', 1), ('tyred', 1), ('couched', 1), ('gain', 1), ('opposed', 1), ('Ore', 1), ('giued', 1), ('eruptions', 1), ('vnderstood', 1), ('Ministers', 1), ('Artlesse', 1), ('inuisible', 1), ('depend', 1), ('Rudenesse', 1), ('heauenly', 1), ('Scene', 1), ('worse', 1), ('found', 1), ('bloud', 1), ('necessaries', 1), ('sauing', 1), ('wife', 1), ('sacrilegious', 1), ('competent', 1), ('loosed', 1)]

# %%
def unusual_words(text):
    text_vocab=set(w.lower() for w in text if w.isalpha())
    english_vocab=set(w.lower() for w in nltk.corpus.words.words())
    unusual=text_vocab.difference(english_vocab)
    return sorted(unusual)

# %%
unused1=unusual_words(nltk.corpus.gutenberg.words( 'shakespeare-caesar.txt'))

# %%
unused2=unusual_words(nltk.corpus.gutenberg.words( 'shakespeare-hamlet.txt'))

# %%
unused3=unusual_words(nltk.corpus.gutenberg.words( 'shakespeare-macbeth.txt'))

# %%
unused_word=unused1+unused2+unused3

# %%
print(unused_word)
# Out:
# ['aboue', 'abridg', 'accents', 'accidentall', 'accoutred', 'acrosse', 'acte', 'acted', 'actors', 'actus', 'adde', 'aduantage', 'aeneas', 'affabilitie', 'affayres', 'affections', 'affraid', 'againe', 'ages', 'alarums', 'alasse', 'alchymie', 'aliue', 'alreadie', 'alwayes', 'amaz', 'ambitions', 'amisse', 'ancestors', 'anchyses', 'angell', 'answere', 'answered', 'answering', 'antonies', 'apes', 'apparant', 'apparrell', 'appeare', 'appearing', 'appeas', 'appertaine', 'applauses', 'apprehensiue', 'arbors', 'arguing', 'arises', 'arme', 'armes', 'armies', 'arriu', 'arriue', 'artemidorus', 'artimedorus', 'arts', 'ascended', 'aske', 'asleepe', 'assur', 'attaine', 'attaines', 'attempts', 'attendants', 'attyre', 'aueng', 'augurers', 'aule', 'auoyd', 'auoyded', 'ayme', 'ayre', 'backe', 'baite', 'banished', 'bankes', 'banquetting', 'bargaine', 'barke', 'barres', 'basest', 'bastardie', 'batchellor', 'batchellour', 'battaile', 'battailes', 'battell', 'battlements', 'beads', 'beards', 'beare', 'beares', 'beasts', 'beene', 'began', 'begg', 'begge', 'beggers', 'begins', 'behauiours', 'behinde', 'beleeue', 'belike', 'belou', 'beloued', 'benches', 'bequeathing', 'besmeare', 'bethinke', 'betweene', 'bids', 'bigge', 'billes', 'birds', 'blacke', 'bleede', 'blew', 'blockes', 'bloodie', 'bloods', 'blowes', 'boldest', 'bolts', 'bondmen', 'bonds', 'bones', 'booke', 'bookes', 'bootlesse', 'bosome', 'bosomes', 'bowle', 'br', 'braines', 'brands', 'brau', 'braue', 'brauely', 'brauery', 'breake', 'breathlesse', 'breefely', 'brest', 'bribes', 'brings', 'brothers', 'browes', 'bru', 'buriall', 'burne', 'burnes', 'burneth', 'busie', 'businesse', 'bussling', 'butchers', 'byrth', 'caes', 'caesars', 'cai', 'caius', 'calles', 'calphurnia', 'cals', 'cancell', 'canst', 'capitoll', 'cappes', 'captiue', 'captiues', 'captiuitie', 'carelesly', 'cares', 'carkasse', 'carries', 'carrions', 'carue', 'cas', 'caska', 'cassi', 'cato', 'cauerne', 'causes', 'ceremonies', 'certaine', 'chace', 'chafing', 'chaire', 'chanc', 'channell', 'charges', 'charme', 'charractery', 'chasticement', 'chayre', 'cheeke', 'cheere', 'chides', 'children', 'choak', 'choaked', 'chollericke', 'chopt', 'cic', 'cicero', 'cimber', 'cin', 'cinna', 'citizens', 'ciuill', 'clamors', 'clapp', 'clau', 'cleane', 'clitus', 'cloake', 'cloakes', 'clocke', 'closset', 'clouds', 'clowds', 'clymate', 'co', 'cobl', 'cobler', 'coffers', 'cogitations', 'coine', 'com', 'combin', 'comets', 'commanders', 'commended', 'comming', 'commoners', 'companies', 'compasse', 'compell', 'concaue', 'conceptions', 'conceyu', 'concluded', 'conditions', 'confesse', 'confines', 'conioyntly', 'coniur', 'coniure', 'conquerors', 'conquests', 'consorted', 'conspiracie', 'conspirators', 'constancie', 'consum', 'contriue', 'contriuer', 'controuersie', 'coronets', 'corpes', 'corporall', 'couchings', 'couer', 'couert', 'couetous', 'councell', 'counsell', 'counsels', 'counters', 'countrey', 'countries', 'countrymen', 'courtesie', 'courtesies', 'cowards', 'craues', 'creatures', 'crests', 'cride', 'crost', 'crowes', 'crowne', 'cruell', 'cryed', 'cryedst', 'curre', 'curtesie', 'curtsies', 'cushions', 'custome', 'cuts', 'cymber', 'cyn', 'cynicke', 'cynna', 'cæsar', 'dangers', 'danke', 'dardanius', 'darke', 'darknesse', 'dayes', 'deafe', 'deale', 'deare', 'deaths', 'dec', 'deceitfull', 'deceiu', 'deci', 'deckt', 'deede', 'deeds', 'deepe', 'deere', 'deerely', 'deerer', 'degrees', 'deliuer', 'deriu', 'describ', 'deseru', 'desir', 'desires', 'desiring', 'deuise', 'dewes', 'dies', 'dignities', 'dimme', 'disclos', 'discouer', 'discouered', 'disgest', 'dishonourable', 'dismisse', 'displeas', 'dispos', 'disposing', 'disprooue', 'diuell', 'diuers', 'diuided', 'diuision', 'doers', 'dogge', 'dogges', 'domesticke', 'doo', 'doomesday', 'doore', 'doores', 'dost', 'doth', 'doubted', 'doubtfull', 'downe', 'drachmaes', 'drawes', 'drawne', 'dreadfull', 'dreame', 'dreames', 'dreampt', 'drinke', 'drinkes', 'driue', 'driuen', 'driues', 'drizel', 'droppes', 'drops', 'dumbe', 'd ...

# %%
top_5=word_counts.most_common(5)

# %%
print(top_5)
# Out:
# [('seauenth', 1), ('rous', 1), ('refus', 1), ('Speake', 1), ('presage', 1)]
