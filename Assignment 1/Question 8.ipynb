# %% [markdown]
# question 8
# Use nps_chat and wordlist corpus.
# If you find a word in nps_chat but not in wordlist, it is considered an unusual word. (e.g. Heyyyy, gr8, 4ever can be considered unusual words for this analysis)
# Find out how many unusual words people speak in chat (notice: usernames should not be counted)
# Bonus: What if I want to  count : ) , : ( all these emoticons in. (optional)

# %%
import nltk

# %%
from nltk.corpus import nps_chat, words

# %%
words.words()
# Out:
# ['A',
#  'a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'Aani',
#  'aardvark',
#  'aardwolf',
#  'Aaron',
#  'Aaronic',
#  'Aaronical',
#  'Aaronite',
#  'Aaronitic',
#  'Aaru',
#  'Ab',
#  'aba',
#  'Ababdeh',
#  'Ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'Abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'Abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'Abanic',
#  'Abantes',
#  'abaptiston',
#  'Abarambo',
#  'Abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'Abasgi',
#  'abash',
#  'abashed',
# ...

# %%
nltk.corpus.nps_chat.fileids()
# Out:
# ['10-19-20s_706posts.xml',
#  '10-19-30s_705posts.xml',
#  '10-19-40s_686posts.xml',
#  '10-19-adults_706posts.xml',
#  '10-24-40s_706posts.xml',
#  '10-26-teens_706posts.xml',
#  '11-06-adults_706posts.xml',
#  '11-08-20s_705posts.xml',
#  '11-08-40s_706posts.xml',
#  '11-08-adults_705posts.xml',
#  '11-08-teens_706posts.xml',
#  '11-09-20s_706posts.xml',
#  '11-09-40s_706posts.xml',
#  '11-09-adults_706posts.xml',
#  '11-09-teens_706posts.xml']

# %%
all_posts = list(nps_chat.words('10-19-20s_706posts.xml')
                 +nps_chat.words('10-19-30s_705posts.xml')
                +nps_chat.words('10-19-40s_686posts.xml')
                +nps_chat.words('10-19-adults_706posts.xml')
                +nps_chat.words('10-24-40s_706posts.xml')
                +nps_chat.words('10-26-teens_706posts.xml')
                 +nps_chat.words('11-06-adults_706posts.xml')                
                +nps_chat.words('11-08-20s_705posts.xml')                 
                 +nps_chat.words('11-08-40s_706posts.xml')
                 +nps_chat.words('11-08-adults_705posts.xml')
                +nps_chat.words('11-08-teens_706posts.xml')
                +nps_chat.words('11-09-20s_706posts.xml')
                +nps_chat.words('11-09-40s_706posts.xml')
                +nps_chat.words('11-09-adults_706posts.xml')
                +nps_chat.words('11-09-teens_706posts.xml'))

# %%
print(all_posts[50:500])
# Out:
# ['go', 'U7', 'do', "n't", 'golf', 'clap', 'me', '.', 'fuck', 'you', 'U121', ':@', 'whats', 'everyone', 'up', 'to', '?', 'PART', 'PART', 'i', "'ll", 'thunder', 'clap', 'your', 'ass', '.', 'PART', 'and', 'i', 'dont', 'even', 'know', 'what', 'that', 'means', '.', 'that', 'sounds', 'painful', 'any', 'ladis', 'wanna', 'chat', '?', '29', 'm', '26', '/', 'm', 'JOIN', 'my', 'cousin', 'drew', 'a', 'messed', 'up', 'pic', 'on', 'my', 'cast', 'PART', '24', '/', 'm', 'boo', '.', '26', '/', 'm', 'and', 'sexy', 'lol', 'U115', 'boo', '.', 'JOIN', 'PART', 'he', 'drew', 'a', 'girl', 'with', 'legs', 'spread', 'boo', '.', 'hope', 'he', 'didnt', 'draw', 'a', 'penis', 'PART', 'ewwwww', 'lol', '&', 'a', 'head', 'between', 'her', 'legs', 'JOIN', 'JOIN', 'sounds', 'good', 'to', 'me', '.', 'r', 'u', 'serious', 'JOIN', 'PART', 'I', "'ll", 'take', 'one', ',', 'please', '.', '&', 'i', 'have', 'to', 'go', 'to', 'the', 'docs', 'tomorrow', 'ya', 'man', 'I', 'am', 'too', '..', 'Connected', 'to', '...', 'Slip', 'away
# ...

# %%
def unusual_words(text):
    text_vocab=set(w.lower() for w in text if w.isalpha())
    english_vocab=set(w.lower() for w in nltk.corpus.words.words())
    unusual=text_vocab.difference(english_vocab)
    return sorted(unusual)

# %%
unusual_words(nltk.corpus.nps_chat.words())
# Out:
# ['aaaaaaaaaaaaaaaaa',
#  'aaahhhh',
#  'abortions',
#  'abou',
#  'abourted',
#  'abs',
#  'ack',
#  'acros',
#  'actualy',
#  'adams',
#  'adds',
#  'adduser',
#  'adjusts',
#  'adoted',
#  'adreniline',
#  'ads',
#  'adults',
#  'afe',
#  'affairs',
#  'affari',
#  'affects',
#  'afk',
#  'agaibn',
#  'ages',
#  'aggravated',
#  'agurlwithbigguns',
#  'ahah',
#  'ahahah',
#  'ahahh',
#  'ahahha',
#  'ahh',
#  'ahhah',
#  'ahhahahaha',
#  'ahhh',
#  'ahhhh',
#  'ahhhhhh',
#  'ahhhhhhhhhhhhhh',
#  'aiiiiiiiiiiiiiiiiiiiiiiii',
#  'aiken',
#  'aime',
#  'akdt',
#  'akon',
#  'akron',
#  'akst',
#  'aligator',
#  'allergies',
#  'allo',
#  'allowed',
#  'aloha',
#  'alohaaa',
#  'alohas',
#  'alot',
#  'alotta',
#  'alternatives',
#  'alterz',
#  'alwys',
#  'alzheimers',
#  'amazingness',
#  'americans',
#  'anithing',
#  'ans',
#  'answering',
#  'answers',
#  'antidepressants',
#  'anygirl',
#  'anymore',
#  'anythin',
#  'anytime',
#  'anyyyyyyyyyyyyyyyyy',
#  'aok',
# ...
